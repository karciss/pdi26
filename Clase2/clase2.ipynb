# %% [markdown]
# Imagenes

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# abrir imagen
img = cv2.imread('perro.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig, axs = plt.subplots(1, 4, figsize=(20, 5))
axs[0].imshow(img_rgb)
axs[0].set_title('Imagen Original')

fig_img = axs[1].imshow(img_rgb[...,0], cmap='gray')
fig.colorbar(fig_img, ax=axs[1], shrink=0.5)
axs[1].set_title('Canal Rojo')


fig_img = axs[2].imshow(img_rgb[...,1], cmap='gray')
fig.colorbar(fig_img, ax=axs[2], shrink=0.5)
axs[2].set_title('Canal Verde')


fig_img = axs[3].imshow(img_rgb[...,2], cmap='gray')
fig.colorbar(fig_img, ax=axs[3], shrink=0.5)
axs[3].set_title('Canal Azul')
# Out:
# Text(0.5, 1.0, 'Canal Azul')

# %%
img_rgb[:3,:3,:]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
# recortar una imagen
plt.imshow(img_rgb[:200,:200,:])

# %%
# guardar imagen
cv2.imwrite('perrito.jpg', img_rgb)
plt.imsave('perro_recortado.jpg',cv2.cvtColor(img_rgb[:200,:200,:], cv2.COLOR_RGB2BGR))

# %% [markdown]
# Ejercicios para generar una imagen

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize']=[10,5]
size_image = 100
R = np.ones((size_image, size_image))*5
G = np.ones((size_image, size_image))*128
B = np.ones((size_image, size_image))*0

imagen = np.dstack((R,G,B))
imagen = np.array(imagen, dtype=int)

plt.figure()
plt.imshow(imagen)
plt.title('Imagen color: Naranja')
plt.show()

# %% [markdown]
# Escala de grises y profundidad de colores

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread('perro.jpg', cv2.IMREAD_GRAYSCALE)

# valores iniciales de proginidad de color
original = img.dtype
# trasfromado la imagen a 16 bits
img16bits = np.uint16(img)
img_new = img16bits.dtype

print('profundidad de color : ', img_new)
# guardado con cv2
# guardado con pyplot

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Imagen original')
plt.imshow(img, cmap='gray')


plt.subplot(1,2,2)
plt.title('Imagen con profundidad de color de 16 bits')
plt.imshow(img16bits, cmap='gray')
# Out:
# profundidad de color :  uint16
